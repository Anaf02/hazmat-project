# %%
# Test Anas Robotflow speed on FH server from Ting
from ultralytics import YOLO

# %%
# Load a model
model = YOLO("runs/detect/train24/weights/last.pt")  # load a partially trained model

# %%
# continue to train Ana's model
results = model.train(
    data="./../data/roboflow_dataset.yaml", 
    epochs=10, 
    imgsz=640, 
    device="mps"
)
# Out:
# New https://pypi.org/project/ultralytics/8.2.42 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (AMD EPYC 7282 16-Core Processor)
# ...

# %%
model.save('../runs/manually/testyolov82/weights.pt')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model.save('../runs/manually/testyolov82')
#
# File /mnt/nvme/home/c2210475174/ana/hazmat-project/hazmat_env/lib/python3.10/site-packages/ultralytics/engine/model.py:335, in Model.save(self, filename, use_dill)
#     327 from ultralytics import __version__
#     329 updates = {
#     330     "date": datetime.now().isoformat(),
#     331     "version": __version__,
#     332     "license": "AGPL-3.0 License (https://ultralytics.com/license)",
#     333     "docs": "https://docs.ultralytics.com",
#     334 }
# --> 335 torch.save({**self.ckpt, **updates}, filename, use_dill=use_dill)
#
# File /mnt/nvme/home/c2210475174/ana/hazmat-project/hazmat_env/lib/python3.10/site-packages/ultralytics/utils/patches.py:87, in torch_save(use_dill, *args, **kwargs)
# ...

# %%
# Resume training after Keyboad interrupt
model = YOLO("../runs/manually/testyolov82/weights.pt")  # load a partially trained model

# Resume training for additional epochs
results = model.train(
    data="./../data/roboflow_dataset.yaml", 
    epochs=1, 
    imgsz=640, 
    device="mps"    # total number of epochs to train, including the previous ones
)
# Out:
# New https://pypi.org/project/ultralytics/8.2.42 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (AMD EPYC 7282 16-Core Processor)
# ...

# %%
# Prediction, Inference on images, videos, streams
from ultralytics import YOLO

# 1. Create an instance of the model/load a model
model = YOLO("../runs/detect/train16/weights/best.pt")  # pretrained YOLOv8n model

# %%
# Prediction, Inference: predict mode for images, videos, life streams
# 2. Do Inference: run batched inference on a list of images
results = model([
    "../data/roboflow/test/images/01.rf.51b331a822cbf8463a5311d5aec10e21.jpg",
    "../data/roboflow/test/images/02_jpg.rf.4cb36207ca9a1649eeaf08fafd37c699.jpg",
    save=True
])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    # result.show()  # display to screen T: (headless environment (without a graphical user interface)
    result.save(filename="result.jpg")  # save to disk
# Out:
# image 1/1 /mnt/nvme/home/c2210475174/ana/hazmat-project/notebooks/../data/roboflow/test/images/01.rf.51b331a822cbf8463a5311d5aec10e21.jpg: 640x640 1 dangerous-when-wet, 1 explosive, 1 flammable, 1 oxidizer, 5.9ms
# Speed: 5.0ms preprocess, 5.9ms inference, 405.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /mnt/nvme/home/c2210475174/ana/hazmat-project/runs/detect/predict2
